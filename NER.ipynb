# %% [markdown]
# <h2 align=center> Named Entity Recognition (NER) using LSTMs with tensorflow.keras</h2>

# %% [markdown]
# ### Task 1: Project Overview and Import Modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
np.random.seed(0)
# plt.style.use("ggplot")

import tensorflow as tf
print('Tensorflow version:', tf.__version__)
print('GPU detected:', tf.config.list_physical_devices('GPU'))
# Out:
# Tensorflow version: 2.5.0-dev20201217
# GPU detected: []

# %% [markdown]
# ### Task 2: Load and Explore the NER Dataset

# %% [markdown]
# *Essential info about tagged entities*:
# - geo = Geographical Entity
# - org = Organization
# - per = Person
# - gpe = Geopolitical Entity
# - tim = Time indicator
# - art = Artifact
# - eve = Event
# - nat = Natural Phenomenon

# %%
data = pd.read_csv("ner_dataset.csv.zip", compression='zip', encoding="latin1")
data = data.fillna(method="ffill")
data.head(20)
# Out:
#      Sentence #           Word  POS    Tag
# 0   Sentence: 1      Thousands  NNS      O
# 1   Sentence: 1             of   IN      O
# 2   Sentence: 1  demonstrators  NNS      O
# 3   Sentence: 1           have  VBP      O
# 4   Sentence: 1        marched  VBN      O
# 5   Sentence: 1        through   IN      O
# 6   Sentence: 1         London  NNP  B-geo
# 7   Sentence: 1             to   TO      O
# 8   Sentence: 1        protest   VB      O
# 9   Sentence: 1            the   DT      O
# 10  Sentence: 1            war   NN      O
# 11  Sentence: 1             in   IN      O
# 12  Sentence: 1           Iraq  NNP  B-geo
# 13  Sentence: 1            and   CC      O
# 14  Sentence: 1         demand   VB      O
# 15  Sentence: 1            the   DT      O
# 16  Sentence: 1     withdrawal   NN      O
# 17  Sentence: 1             of   IN      O
# 18  Sentence: 1        British   JJ  B-gpe
# 19  Sentence: 1         troops  NNS      O

# %%
print("Unique words in corpus:", data['Word'].nunique())
print("Unique tags in corpus:", data['Tag'].nunique())
# Out:
# Unique words in corpus: 35178
# Unique tags in corpus: 17

# %%
words = list(set(data["Word"].values))
words.append("ENDPAD")
num_words = len(words)

# %%
tags = list(set(data["Tag"].values))
num_tags = len(tags)

# %% [markdown]
# ### Task 3: Retrieve Sentences and Corresponsing Tags

# %%
class SentenceGetter(object):
    def __init__(self, data):
        self.n_sent = 1
        self.data = data
        self.empty = False
        agg_func = lambda s: [(w, p, t) for w, p, t in zip(s["Word"].values.tolist(),
                                                           s["POS"].values.tolist(),
                                                           s["Tag"].values.tolist())]
        self.grouped = self.data.groupby("Sentence #").apply(agg_func)
        self.sentences = [s for s in self.grouped]
    
    def get_next(self):
        try:
            s = self.grouped["Sentence: {}".format(self.n_sent)]
            self.n_sent += 1
            return s
        except:
            return None

# %%
getter = SentenceGetter(data)
sentences = getter.sentences

# %%
sentences[0]
# Out:
# [('Thousands', 'NNS', 'O'),
#  ('of', 'IN', 'O'),
#  ('demonstrators', 'NNS', 'O'),
#  ('have', 'VBP', 'O'),
#  ('marched', 'VBN', 'O'),
#  ('through', 'IN', 'O'),
#  ('London', 'NNP', 'B-geo'),
#  ('to', 'TO', 'O'),
#  ('protest', 'VB', 'O'),
#  ('the', 'DT', 'O'),
#  ('war', 'NN', 'O'),
#  ('in', 'IN', 'O'),
#  ('Iraq', 'NNP', 'B-geo'),
#  ('and', 'CC', 'O'),
#  ('demand', 'VB', 'O'),
#  ('the', 'DT', 'O'),
#  ('withdrawal', 'NN', 'O'),
#  ('of', 'IN', 'O'),
#  ('British', 'JJ', 'B-gpe'),
#  ('troops', 'NNS', 'O'),
#  ('from', 'IN', 'O'),
#  ('that', 'DT', 'O'),
#  ('country', 'NN', 'O'),
#  ('.', '.', 'O')]

# %% [markdown]
# ### Task 4: Define Mappings between Sentences and Tags

# %%
word2idx = {w: i + 1 for i, w in enumerate(words)}
tag2idx = {t: i for i, t in enumerate(tags)}

# %%
word2idx
# Out:
# {'Hina': 1,
#  'Erik': 2,
#  'Outside': 3,
#  'military-political': 4,
#  'escapees': 5,
#  'admiration': 6,
#  '28th': 7,
#  'Consensus': 8,
#  'deflected': 9,
#  'disguised': 10,
#  'doves': 11,
#  'relating': 12,
#  'wings': 13,
#  'useful': 14,
#  'spacewalking': 15,
#  'transitioning': 16,
#  'disabling': 17,
#  'requires': 18,
#  'practices': 19,
#  'Benita': 20,
#  'similar': 21,
#  'Potro': 22,
#  'uranium-enrichment': 23,
#  'Bell': 24,
#  'mentions': 25,
#  'loosened': 26,
#  'talked': 27,
#  'funnel': 28,
#  'Scotland': 29,
#  'parity': 30,
#  'uproar': 31,
#  'El-Obeid': 32,
#  'Indonesian': 33,
#  'uncertainty': 34,
#  'Foreigners': 35,
#  'moment': 36,
#  'Palm': 37,
#  '98': 38,
#  'Javed': 39,
#  'hemp': 40,
#  'servicing': 41,
#  'Cycling': 42,
#  'Herb': 43,
#  'Savannah': 44,
#  'fine': 45,
#  'Seventh': 46,
#  'expect': 47,
#  'Nyange': 48,
#  'Spanish-language': 49,
#  'eggplant': 50,
#  'towers': 51,
#  'lightly-populated': 52,
#  '84.9': 53,
#  'Nagin': 54,
#  'Ghassan': 55,
#  'Ansari': 56,
#  '1644': 57,
#  'non-aligned': 58,
#  'Observer': 59,
#  'Jawid': 60,
#  'Reserve': 61,
#  'beating': 62,
#  'heat': 63,
#  'trained': 64,
#  'siege': 65,
#  'Timidria': 66,
#  'ocean': 67,
#  'Drought': 68,
#  'Saidati': 69,
#  'Togoland': 70,
#  'occasions': 71,
#  'survivors': 72,
#  '6,78,000': 73,
#  'ago': 74,
#  'GlaxoSmithKline': 75,
#  'secrets': 76,
#  'Fattal': 77,
#  'contrive': 78,
#  '93.3': 79,
#  'Cadmium': 80,
#  'Buffett': 81,
#  'funk': 82,
#  'Tshisekedi': 83,
#  'Yekhanurov': 84,
#  '34-17': 85,
#  'surgical': 86,
#  'burned-out': 87,
#  'Steyn': 88,
#  'Video': 89,
#  'foods': 90,
#  'Chilitepic': 91,
#  'Divas': 92,
#  'Houses': 93,
#  'uncontrolled': 94,
#  'reckon': 95,
#  'deceive': 96,
#  'palm': 97,
#  'sponsoring': 98,
#  'Looting': 99,
#  'Rugigana': 100,
#  'Voreqe': 101,
#  'Cardinal': 102,
#  'Helicopter': 103,
#  'tend': 104,
#  'Kitty': 105,
#  'Shalom': 106,
#  'farthest': 107,
#  'pipelines': 108,
#  'Bombardier': 109,
#  'vacancy': 110,
#  'Large': 111,
#  'African-inhabited': 112,
#  'Behold': 113,
#  'browsing': 114,
#  'pop': 115,
#  'dashing': 116,
#  'Bayu': 117,
#  'biathletes': 118,
#  'Makhachkala': 119,
#  'Grinstein': 120,
#  'Lantos': 121,
#  'teaches': 122,
#  'forgery': 123,
#  'Dent': 124,
#  'Draskovic': 125,
#  'Extended': 126,
#  'Guest': 127,
#  'Albar': 128,
#  'XI': 129,
#  'tapered': 130,
#  'Members': 131,
#  'Improvised': 132,
#  'cancer': 133,
#  'willing': 134,
#  'Tahseen': 135,
#  'conspicuous': 136,
#  'royal': 137,
#  'Rhine-Westphalia': 138,
#  'Al-Hashimi': 139,
#  'Abul': 140,
#  'Cheek': 141,
#  'repairing': 142,
#  '1899': 143,
#  'Aberrahman': 144,
#  'Turkish-dominated': 145,
#  'adhesive': 146,
#  'eradication': 147,
#  'Ghormley': 148,
#  'tram': 149,
#  'biblical': 150,
#  'persecuted': 151,
#  'slid': 152,
#  '1912': 153,
#  'voided': 154,
#  'Lyon': 155,
#  'Spiegel': 156,
#  'instructed': 157,
#  'Vajpayee': 158,
#  'recognizes': 159,
#  'Jeep': 160,
#  'victory': 161,
#  'normally': 162,
#  'Yugansk': 163,
#  '8.4': 164,
#  'delivering': 165,
#  'Accra': 166,
#  'evacuate': 167,
#  'formulas': 168,
#  'pivotal': 169,
#  'construct': 170,
#  'climbing': 171,
#  'homicide': 172,
#  'Freetown': 173,
#  'Bhaikaji': 174,
#  'disintegration': 175,
#  'prototype': 176,
#  'Urdu-speaking': 177,
#  '890': 178,
#  '784': 179,
#  'couples': 180,
#  'civilly': 181,
#  'trimming': 182,
#  'scope': 183,
#  'Adil': 184,
#  'hailed': 185,
#  'hailing': 186,
#  'Mykola': 187,
#  'redeployed': 188,
#  'haunch': 189,
#  'Anglo-Spanish': 190,
#  'wisdom': 191,
#  'charges': 192,
#  'Gnassingbe': 193,
#  'comfort': 194,
#  'Mosul': 195,
#  'disdain': 196,
#  'investigation': 197,
#  'Zimmermann': 198,
#  'shut': 199,
#  'indications': 200,
#  'unidentifed': 201,
#  'representation': 202,
#  'de-furred': 203,
#  'commemorated': 204,
#  'initiation': 205,
#  'Bigombe': 206,
#  'Soviet-imposed': 207,
#  'first-set': 208,
#  'mourns': 209,
#  'Professionals': 210,
#  'Sadeh': 211,
#  'Understanding': 212,
#  'comatose': 213,
#  'nearly-naked': 214,
#  'careful': 215,
#  'Hayward': 216,
#  'Compay': 217,
#  'stabbed': 218,
#  'Bihari': 219,
#  'Grozny': 220,
#  'recurring': 221,
#  'Assadullah': 222,
#  '21.3': 223,
#  'stealing': 224,
#  'emerging': 225,
#  'sauropods': 226,
#  'panorama': 227,
#  'Pickens': 228,
#  'mismanaging': 229,
#  'Communication': 230,
#  'Ghazala': 231,
#  'Tartus': 232,
#  'corn': 233,
#  'KIRCHNER': 234,
#  'Rocco': 235,
#  'transported': 236,
#  'Swedes': 237,
#  'moderated': 238,
#  'Ah': 239,
#  'NSA': 240,
#  'discount': 241,
#  '11-year': 242,
#  'Borges': 243,
#  'Plummer': 244,
#  '1.27': 245,
#  'Abdul-Hussein': 246,
#  '85': 247,
#  'transportation': 248,
#  'Brazilian-made': 249,
#  'Sahel': 250,
#  'landmarks': 251,
#  'Nyamwasa': 252,
#  '800-meter-wide': 253,
#  'Oath': 254,
#  'Leroy': 255,
#  'quarrel': 256,
#  'historic': 257,
#  'Small-scale': 258,
#  'Fitzpatrick': 259,
#  'Ashura': 260,
#  'Robben': 261,
#  'shrunk': 262,
#  'integrity': 263,
#  'obey': 264,
#  'Celia': 265,
#  'district': 266,
#  'redistricting': 267,
#  'Domino': 268,
#  'punitive': 269,
#  'idle': 270,
#  'five-story': 271,
#  'nasty': 272,
#  'Abdel-Rahman': 273,
#  'Wannian': 274,
#  'underreported': 275,
#  'jcfundrzr@aol.com': 276,
#  'Jewelers': 277,
#  'state-owned': 278,
#  'colder': 279,
#  'no': 280,
#  'jumped': 281,
#  'border-crossing': 282,
#  'spray': 283,
#  'Hancock': 284,
#  'immediate': 285,
#  'assumes': 286,
#  'clarification': 287,
#  'Mahara': 288,
#  'Al-Rai': 289,
#  'pupils': 290,
#  'Kruif': 291,
#  'richest': 292,
#  'neighborhoods': 293,
#  'parade': 294,
#  'grossed': 295,
#  'Rabdhure': 296,
#  'knowingly': 297,
#  'truckloads': 298,
#  'gasoline': 299,
#  'infections': 300,
#  'degree': 301,
#  'compiler': 302,
#  'nails': 303,
#  'Stiller': 304,
#  'Bhat': 305,
#  'transmitting': 306,
#  'prizes': 307,
#  'Afar': 308,
#  '250,000-member': 309,
#  'Hepburn': 310,
#  'physical': 311,
#  'Indra': 312,
#  'crush': 313,
#  'anytime': 314,
#  'Extremists': 315,
#  'delegated': 316,
#  'anti-war': 317,
#  'Topolanek': 318,
#  '25-year': 319,
#  'Poupard': 320,
#  'Pirates': 321,
#  'deciphering': 322,
#  'midday': 323,
#  'Spokesmen': 324,
#  'erosion': 325,
#  'Satan': 326,
#  'Linas-Marcoussis': 327,
#  '11-style': 328,
#  'Fequiere': 329,
#  'Great': 330,
#  'fruitful': 331,
#  '32.7': 332,
#  'Craybas': 333,
#  'Blitz': 334,
#  'arrow': 335,
#  'retained': 336,
#  '267': 337,
#  'Kunar': 338,
#  'sides': 339,
#  'Alkhanov': 340,
#  'custody': 341,
#  'Flight': 342,
#  'expiration': 343,
#  'preserved': 344,
#  'heart': 345,
#  'praise': 346,
#  'Islets': 347,
#  'disinfected': 348,
#  'distributor': 349,
#  'dies': 350,
#  'Wisconsin': 351,
#  'Everybody': 352,
#  'Maghazi': 353,
#  'Dakhil': 354,
#  '185': 355,
#  'pilotless': 356,
#  'loosen': 357,
#  'Felipe': 358,
#  'Rigoberta': 359,
#  'mangos': 360,
#  'Cooperativa': 361,
#  'ruble': 362,
#  'Mironov': 363,
#  'complimentary': 364,
#  'migrating': 365,
#  'disease-causing': 366,
#  'Walter': 367,
#  'THIEF': 368,
#  'pretrial': 369,
#  'Anheuser-Busch': 370,
#  'prevent': 371,
#  'Dominicans': 372,
#  'staffer': 373,
#  'Basutoland': 374,
#  'pre-World': 375,
#  'ambiguous': 376,
#  'Latgalians': 377,
#  'conniving': 378,
#  'unusually': 379,
#  'deeply': 380,
#  'brutally': 381,
#  'Sectarian': 382,
#  'boyhood': 383,
#  'creatures': 384,
#  'JDX': 385,
#  'graft': 386,
#  'depending': 387,
#  'Bilfinger': 388,
#  'smothered': 389,
#  'Mashjid': 390,
#  'Vehicle': 391,
#  'Frank-Walter': 392,
#  'forested': 393,
#  'sea-level': 394,
#  'power-sharing': 395,
#  'first-class': 396,
#  'Dahomey': 397,
#  'refueling': 398,
#  'mistreated': 399,
#  'Solo': 400,
#  'initialed': 401,
#  'grandchild': 402,
#  'Nov.': 403,
#  '7,000-member': 404,
#  'Saderat': 405,
#  'novelist': 406,
#  'depleting': 407,
#  'Epsilon': 408,
#  '9,34,000': 409,
#  'Sherpao': 410,
#  'Luzon': 411,
#  'aides': 412,
#  'Mikasa': 413,
#  'Abdullah': 414,
#  'SPENCER': 415,
#  'singer': 416,
#  'Africans': 417,
#  'Manx': 418,
#  'Baghdadi': 419,
#  'Bean': 420,
#  'California-Mexico': 421,
#  'Cuomo': 422,
#  'poked': 423,
#  'tension': 424,
#  'al-Faisal': 425,
#  'flagon': 426,
#  'charger': 427,
#  'Domm': 428,
#  'protected': 429,
#  'Anhui': 430,
#  'Department': 431,
#  'identity': 432,
#  'Lion': 433,
#  'Naxalites': 434,
#  'Bangladesh': 435,
#  'Chubais': 436,
#  'institute': 437,
#  'Somalia-linked': 438,
#  'Red': 439,
#  'Christians': 440,
#  'French-Colombian': 441,
#  'Smolensk': 442,
#  'turn': 443,
#  'always': 444,
#  'El~Arish': 445,
#  '266': 446,
#  'signatories': 447,
#  'Rowan': 448,
#  'Hedi': 449,
#  'definitely': 450,
#  'mbalax': 451,
#  'Pagonis': 452,
#  'Ga.': 453,
#  '87': 454,
#  'rightwing': 455,
#  'Faxas': 456,
#  'Vikings': 457,
#  'Kazemi': 458,
#  'accelerated': 459,
#  'RCTV': 460,
#  'Maurits': 461,
#  'Besides': 462,
#  'military-related': 463,
#  'divide-and-rule': 464,
#  'coals': 465,
#  'adapted': 466,
#  'cylinder': 467,
#  'success': 468,
#  'intensified': 469,
#  '1.28.01': 470,
#  'Tolima': 471,
#  '135': 472,
#  'attend': 473,
#  'Otton': 474,
#  'quadriplegic': 475,
#  'conscription': 476,
#  'expenses': 477,
#  'Salang': 478,
#  'Rabiyaa': 479,
#  'rapid': 480,
#  'Federico': 481,
#  'below-average': 482,
#  'Cimoszewicz': 483,
#  'banquet': 484,
#  'PO/PSL': 485,
#  'Justin': 486,
#  'high-profile': 487,
#  'decrease': 488,
#  'Someone': 489,
#  'heeding': 490,
#  'wrongfully': 491,
#  'Griffal': 492,
#  'elevation': 493,
#  'Megumi': 494,
#  'geology': 495,
#  'Shawn': 496,
#  'Arawak': 497,
#  'NSC': 498,
#  'MV': 499,
#  'remove': 500,
#  '650-million': 501,
#  'factory': 502,
#  'Shaffi': 503,
#  'official': 504,
#  'place': 505,
#  'Nuristan': 506,
#  'challenged': 507,
#  'Mohanna': 508,
#  'culminates': 509,
#  'Somme': 510,
#  'Anabel': 511,
#  'missiles': 512,
#  'Youssef': 513,
#  'Virginie': 514,
#  'detective': 515,
#  'Afars': 516,
#  'governmental': 517,
#  'Museum': 518,
#  'Zeid': 519,
#  'Tuol': 520,
#  'Chiao': 521,
#  '18-day': 522,
#  'CPPCC': 523,
#  'pre-Islamic': 524,
#  'Australian': 525,
#  'NIST': 526,
#  'pretax': 527,
#  'Tibetan-American': 528,
#  'Geneva-based': 529,
#  'annexation': 530,
#  'Sideways': 531,
#  'Fried': 532,
#  'Vanhanen': 533,
#  'Securitate': 534,
#  'react': 535,
#  'Chargers': 536,
#  'Boluk': 537,
#  'Secularists': 538,
#  '1925': 539,
#  'inhuman': 540,
#  'reconstituted': 541,
#  'Malenchenko': 542,
#  'clinch': 543,
#  'Paerson': 544,
#  'lawbreakers': 545,
#  'harden': 546,
#  'boldness': 547,
#  'Chibebe': 548,
#  'sustainability': 549,
#  'salesmen': 550,
#  'Raising': 551,
#  'stockholders': 552,
#  'beatboxers': 553,
#  'joyful': 554,
#  'collapses': 555,
#  'Resource-rich': 556,
#  'cough': 557,
#  '82': 558,
#  'missile': 559,
#  'Juncker': 560,
#  'country-level': 561,
#  'Tanith': 562,
#  'commands': 563,
#  'Bystanders': 564,
#  'Praise': 565,
#  'undersecretary': 566,
#  'parmesan': 567,
#  'Rania': 568,
#  'acceptances': 569,
#  'Moken': 570,
#  'confessions': 571,
#  'Vaccine': 572,
#  'shortly': 573,
#  'Arabia': 574,
#  'Jakob': 575,
#  'Endangered': 576,
#  'endeavoured': 577,
#  'Ferrero': 578,
#  'Gokcek': 579,
#  'Ganiyev': 580,
#  'Medak': 581,
#  'Colombo': 582,
#  'multi-racial': 583,
#  'Jabir': 584,
#  'Kentucky': 585,
#  'Ghraib': 586,
#  'assistance': 587,
#  'mm': 588,
#  'skeptics': 589,
#  'bereavement': 590,
#  '88': 591,
#  'home': 592,
#  'king': 593,
#  'almost': 594,
#  'Dragan': 595,
#  'Banjul': 596,
#  'Snagovo': 597,
#  'jaws': 598,
#  'Abel-Rahim': 599,
#  'Dean': 600,
#  'plays': 601,
#  'incest': 602,
#  'Ryan': 603,
#  'prized': 604,
#  'broke': 605,
#  'Organizers': 606,
#  'graduating': 607,
#  'Broadus': 608,
#  'popular': 609,
#  'plates': 610,
#  'agree': 611,
#  'negate': 612,
#  'giant': 613,
#  'sketch': 614,
#  'BACAR': 615,
#  'Hughes': 616,
#  'Newman': 617,
#  'ended': 618,
#  'chute': 619,
#  'onward': 620,
#  'look': 621,
#  'hindrance': 622,
#  'Abdikadir': 623,
#  'English-language': 624,
#  'raffle': 625,
#  'UNICEF': 626,
#  'told': 627,
#  'French-Spanish-Swiss': 628,
#  'Mussolini': 629,
#  'neutrality': 630,
#  'nova': 631,
#  'believes': 632,
#  '1004': 633,
#  'Pearl': 634,
#  'white-clad': 635,
#  'Evan': 636,
#  'kidnap': 637,
#  'unforgivable': 638,
#  'Napa': 639,
#  'reporters': 640,
#  'secession': 641,
#  'Houze': 642,
#  'rituals': 643,
#  'greedily': 644,
#  'proved': 645,
#  'consolidation': 646,
#  'pilots': 647,
#  'predator': 648,
#  'Bellerive': 649,
#  'economics': 650,
#  'Norway': 651,
#  'Martinin': 652,
#  'ferrying': 653,
#  'discharge': 654,
#  'Zanu-PF': 655,
#  'tell-all': 656,
#  'Mosleshi': 657,
#  'firsts': 658,
#  'highly-competitive': 659,
#  'Asadabad': 660,
#  'Triomphe': 661,
#  'Body': 662,
#  'dad': 663,
#  'Porto': 664,
#  'Experts': 665,
#  'fine-tuning': 666,
#  'Ravi': 667,
#  'alternately': 668,
#  'foil': 669,
#  'pearls': 670,
#  'acquisitions': 671,
#  'Hormuz': 672,
#  'KEELING': 673,
#  'SAAKASHVILI': 674,
#  'Jilani': 675,
#  'receded': 676,
#  'Diversification': 677,
#  'skirted': 678,
#  'commandoes': 679,
#  'Claudio': 680,
#  'adamant': 681,
#  'flapped': 682,
#  'sugars': 683,
#  'so': 684,
#  'source': 685,
#  'somber': 686,
#  'hoard': 687,
#  'Corporate': 688,
#  'Saed': 689,
#  'ca.': 690,
#  'Algerian-based': 691,
#  "al-U'Zayra": 692,
#  'Fortaleza': 693,
#  'Jubilee': 694,
#  'audiotape': 695,
#  'arose': 696,
#  'Revenues': 697,
#  '104.6': 698,
#  'Pharaohs': 699,
#  'Ningxia': 700,
#  'Folk': 701,
#  'importunities': 702,
#  'Natalia': 703,
#  'Mauritian': 704,
#  'shaky': 705,
#  'misuse': 706,
#  'run-up': 707,
#  'Debt': 708,
#  'Afghan-international': 709,
#  '600-meter-long': 710,
#  '105.97': 711,
#  'fix': 712,
#  'Queensland': 713,
#  'Gaelic': 714,
#  'warheads': 715,
#  'exempt': 716,
#  'disperse': 717,
#  'Left': 718,
#  'Management': 719,
#  'self-government': 720,
#  'Awantipora': 721,
#  'heed': 722,
#  'see': 723,
#  'alternative-medicine': 724,
#  'Alexy': 725,
#  'FY09': 726,
#  'Rossi': 727,
#  'gum': 728,
#  'tyrants': 729,
#  'lavish': 730,
#  'girls': 731,
#  'purifying': 732,
#  'reminded': 733,
#  'retaliated': 734,
#  'line': 735,
#  'Hrbaty': 736,
#  'Kamel': 737,
#  'enclaves': 738,
#  'frontrunner': 739,
#  'prediction': 740,
#  '543-member': 741,
#  'initial': 742,
#  'cleanup': 743,
#  'pre-paid': 744,
#  'civil': 745,
#  'inlets': 746,
#  'awaiting': 747,
#  'schedules': 748,
#  '70.8': 749,
#  'inspecting': 750,
#  'Twenty-seven': 751,
#  'Bern': 752,
#  'unlucky': 753,
#  'much-honored': 754,
#  'Hamas-ruled': 755,
#  'Blades': 756,
#  'Ayalon': 757,
#  'intense': 758,
#  'Rowsch': 759,
#  '1,157': 760,
#  'malaria-fighting': 761,
#  'purification': 762,
#  'humor': 763,
#  'Gulzar': 764,
#  'emancipation': 765,
#  'chains': 766,
#  'Debris': 767,
#  'Speakers': 768,
#  'curtains': 769,
#  'pediatricians': 770,
#  'Zurabishvili': 771,
#  'conga': 772,
#  '4,500': 773,
#  'un-Islamic': 774,
#  'theirs': 775,
#  'Nadu': 776,
#  'thanking': 777,
#  'exchanging': 778,
#  'disorder': 779,
#  'Plame': 780,
#  'Davydenko': 781,
#  'Israel-Hezbollah': 782,
#  'African-American': 783,
#  'Rasheed': 784,
#  'Rodong': 785,
#  'Noormohammadi': 786,
#  'Cocks': 787,
#  'apiece': 788,
#  'tenure': 789,
#  'truss': 790,
#  'urban': 791,
#  'integrated': 792,
#  'best': 793,
#  'perchance': 794,
#  'frog': 795,
#  'Shepherds': 796,
#  'bandits': 797,
#  'Scheuer': 798,
#  'Kember': 799,
#  'brands': 800,
#  'Ottawa': 801,
#  'sheep-and-cattle': 802,
#  'Veselin': 803,
#  'Racism': 804,
#  'according': 805,
#  'Surgical': 806,
#  'Hague-based': 807,
#  'Graphic': 808,
#  'nation-states': 809,
#  'consider': 810,
#  'Hispanics': 811,
#  'Purina': 812,
#  'handovers': 813,
#  'monarch': 814,
#  'Iranian-made': 815,
#  'Lahi': 816,
#  'knock': 817,
#  '94.2': 818,
#  'indebtedness': 819,
#  'periodic': 820,
#  'spirits': 821,
#  'Uhstad': 822,
#  'Reinsurance': 823,
#  'Si': 824,
#  'levee': 825,
#  'filberts': 826,
#  'repaired': 827,
#  'orbiter': 828,
#  'Heart': 829,
#  'enroll': 830,
#  'Cachaito': 831,
#  'Tens': 832,
#  'trillions': 833,
#  'Uwezo': 834,
#  'Gurung': 835,
#  'prove': 836,
#  'submarines': 837,
#  'like': 838,
#  'Helmut': 839,
#  'replied': 840,
#  'require': 841,
#  'encompass': 842,
#  'excellence': 843,
#  'Softball': 844,
#  'performance': 845,
#  'Wong': 846,
#  'fauna': 847,
#  'Injured': 848,
#  'professors': 849,
#  'Tyrone': 850,
#  'miliatry': 851,
#  '254': 852,
#  'guidance': 853,
#  'Apollo': 854,
#  'League-N': 855,
#  'contest': 856,
#  'Nepal-United': 857,
#  'yield': 858,
#  'Moussaieff': 859,
#  'chopper': 860,
#  'Protected': 861,
#  'Subsistence': 862,
#  'perfumes': 863,
#  'hostess': 864,
#  'bolster': 865,
#  'dietary': 866,
#  'conferences': 867,
#  'bovine': 868,
#  'obsolete': 869,
#  'billion-dollar': 870,
#  'landmark': 871,
#  'Pervez': 872,
#  'Gulbuddin': 873,
#  'lntelligence': 874,
#  'Jury': 875,
#  'expensively': 876,
#  'dealt': 877,
#  '55-to-45': 878,
#  'shootouts': 879,
#  'recover': 880,
#  'Sderot': 881,
#  'Sandstorms': 882,
#  'African-based': 883,
#  'Tibetan': 884,
#  'Summits': 885,
#  'inaugural': 886,
#  'seats': 887,
#  'indicates': 888,
#  'Attackers': 889,
#  'mortally': 890,
#  'Captured': 891,
#  'gaming': 892,
#  'closest': 893,
#  '\x85': 894,
#  'destabilized': 895,
#  'partnerships': 896,
#  'Citta': 897,
#  'against': 898,
#  'NATO-Russia': 899,
#  'Aquatics': 900,
#  'four-fifths': 901,
#  'petitioned': 902,
#  'reflections': 903,
#  'wolf': 904,
#  'potatoes': 905,
#  'referring': 906,
#  'honored': 907,
#  'higher': 908,
#  'attributes': 909,
#  'bulk': 910,
#  'did': 911,
#  'computer-related': 912,
#  'Yuriy': 913,
#  'Annexed': 914,
#  'anyplace': 915,
#  'Fayoum': 916,
#  'Frontrunner': 917,
#  'Communist': 918,
#  'Shorish': 919,
#  '463': 920,
#  'agrees': 921,
#  'checking': 922,
#  'Sunamganj': 923,
#  'Nagano': 924,
#  'suspension': 925,
#  'Robinson': 926,
#  '10-Dec': 927,
#  'al-Maliky': 928,
#  'oil-for-food': 929,
#  'Charges': 930,
#  'Naankuse': 931,
#  'seawater': 932,
#  'dispenses': 933,
#  'cartoonists': 934,
#  '1200': 935,
#  'Cayenne': 936,
#  'Sociology': 937,
#  'Karnataka': 938,
#  'ghettos': 939,
#  'Metallurgy': 940,
#  'non-nuclear': 941,
#  'chewing': 942,
#  '1331': 943,
#  'reaffirm': 944,
#  'hilltop': 945,
#  'Fiat': 946,
#  'fasteners': 947,
#  'impact': 948,
#  'assassin': 949,
#  'brewed': 950,
#  'Subhadra': 951,
#  'Azov': 952,
#  'appreciation': 953,
#  'Infrared': 954,
#  'roast': 955,
#  'flying': 956,
#  'liter': 957,
#  'supply': 958,
#  'Cote': 959,
#  'centered': 960,
#  'Sheik': 961,
#  'sharpened': 962,
#  'deceitful': 963,
#  'commandeered': 964,
#  'regulates': 965,
#  'establishes': 966,
#  'HMAS': 967,
#  'Lennox': 968,
#  'grenades': 969,
#  'second-highest': 970,
#  'Essam': 971,
#  'Resources': 972,
#  'dialed': 973,
#  'Discussions': 974,
#  'facilitator': 975,
#  'Roed-Larsen': 976,
#  'Prix': 977,
#  'Guanglie': 978,
#  'Luxury': 979,
#  'uncover': 980,
#  'Victory': 981,
#  'Teir': 982,
#  'CHARCOAL-BURNER': 983,
#  'Bowman': 984,
#  'pro-Democracy': 985,
#  'stray': 986,
#  'attends': 987,
#  'Secretary-General': 988,
#  'forcibly': 989,
#  'irrigation': 990,
#  'pounce': 991,
#  'credible': 992,
#  'Likud': 993,
#  'Gulf-area': 994,
#  'gymnasiums': 995,
#  'late-year': 996,
#  'cream': 997,
#  'stints': 998,
#  'protectorates': 999,
#  'checks': 1000,
#  ...}

# %% [markdown]
# ### Task 5: Padding Input Sentences and Creating Train/Test Splits

# %%
plt.hist([len(s) for s in sentences], bins=50)
plt.title('Sentences Lengths')
plt.grid()
plt.show();

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

max_len = 50

X = [[word2idx[w[0]] for w in s] for s in sentences]
X = pad_sequences(maxlen=max_len, sequences=X, padding="post", value=num_words-1)

y = [[tag2idx[w[2]] for w in s] for s in sentences]
y = pad_sequences(maxlen=max_len, sequences=y, padding="post", value=tag2idx["O"])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %% [markdown]
# ### Task 6: Build and Compile a Bidirectional LSTM Model

# %%
from tensorflow.keras import Model, Input
from tensorflow.keras.layers import LSTM, Embedding, Dense
from tensorflow.keras.layers import TimeDistributed, SpatialDropout1D, Bidirectional

# %%
input_word = Input(shape=(max_len,))
model = Embedding(input_dim=num_words, output_dim=50, input_length=max_len)(input_word)
model = SpatialDropout1D(0.1)(model)
model = Bidirectional(LSTM(units=100, return_sequences=True, recurrent_dropout=0.1))(model)
out = TimeDistributed(Dense(num_tags, activation="softmax"))(model)
model = Model(input_word, out)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 50)]              0
# _________________________________________________________________
# embedding (Embedding)        (None, 50, 50)            1758950
# _________________________________________________________________
# spatial_dropout1d (SpatialDr (None, 50, 50)            0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 50, 200)           120800
# _________________________________________________________________
# time_distributed (TimeDistri (None, 50, 17)            3417
# =================================================================
# Total params: 1,883,167
# Trainable params: 1,883,167
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="adam",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# %% [markdown]
# ### Task 7: Train the Model

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from livelossplot.tf_keras import PlotLossesCallback

# %%
# %%time

chkpt = ModelCheckpoint("model_weights.h5", monitor='val_loss',verbose=1, save_best_only=True, save_weights_only=True, mode='min')

early_stopping = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=1, verbose=0, mode='max', baseline=None)

callbacks = [PlotLossesCallback(), chkpt, early_stopping]

history = model.fit(x_train, y_train, validation_data=(x_test,y_test), batch_size=32, epochs=3,
                    callbacks=callbacks, verbose=1)
# Out:
# accuracy
# 	training         	 (min:    0.960, max:    0.989, cur:    0.989)
# 	validation       	 (min:    0.982, max:    0.986, cur:    0.986)
# Loss
# 	training         	 (min:    0.036, max:    0.174, cur:    0.036)
# 	validation       	 (min:    0.049, max:    0.064, cur:    0.049)
#
# Epoch 00003: val_loss improved from 0.05067 to 0.04899, saving model to model_weights.h5
# CPU times: user 16min 37s, sys: 3min 49s, total: 20min 26s
# Wall time: 8min 49s

# %% [markdown]
# ### Task 8: Evaluate Named Entity Recognition Model

# %%
model.evaluate(x_test, y_test)
# Out:
# 300/300 [==============================] - 7s 24ms/step - loss: 0.0490 - accuracy: 0.9856
# [0.04898533225059509, 0.9856421947479248]

# %%
i = np.random.randint(0, x_test.shape[0])
p = model.predict(np.array([x_test[i]]))
p = np.argmax(p, axis=-1)
y_true = y_test[i]
print("{:15}{:5}\t {}\n".format("Word", "True", "Pred"))
print("-" *30)
for w, true, pred in zip(x_test[i], y_true, p[0]):
    print("{:15}{}\t{}".format(words[w-1], tags[true], tags[pred]))
# Out:
# Word           True 	 Pred
#
# ------------------------------
# Shaima         B-per	O
# Rezayee        I-per	B-per
# had            O	O
# presented      O	O
# a              O	O
# music          O	O
# program        O	O
# on             O	O
# the            O	O
# privately-run  O	O
# television     O	O
# channel        O	O
# Tolo           B-org	B-org
# TV             I-org	I-org
# ,              O	O
# and            O	O
# was            O	O
# shot           O	O
# in             O	O
# the            O	O
# head           O	O
# in             O	O
# the            B-geo	O
# Kabul          I-geo	B-geo
# neighborhood   O	O
# of             O	O
# Char           B-org	O
# Qala           I-org	I-org
# on             O	O
# Wednesday      B-tim	B-tim
# .              O	O
# out            O	O
# out            O	O
# out            O	O
# out            O	O
# out            O	O
# out            O	O
# out            O	O
# out            O	O
# out            O	O
# out            O	O
# out            O	O
# out            O	O
# out            O	O
# out            O	O
# out            O	O
# out            O	O
# out            O	O
# out            O	O
# out            O	O
